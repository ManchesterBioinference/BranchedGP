# %%
import numpy as np
import time
import GPflow
import numpy as np
import time
import cPickle as pickle
import assigngp_dense
from matplotlib import pyplot as plt
# %matplotlib inline
import VBHelperFunctions
import mouseQPCRModelSelection

# %%
pt,Yall = mouseQPCRModelSelection.LoadMouseQPCRData(subsetSelection=0)
# Out:
# Loaded GPLVM data/guo_ssData.p with nrowsXncols = (437, 2).
# LoadMouseQPCRData output

# %%
import pods
g = 'Id2'
print  'Load gene expression'
data = pods.datasets.singlecell()
genes = data['Y']  
Y = genes[g].values[:,None]    
t0=time.time()  
N = Y.shape[0]
labels = data['labels']
stageCell = np.zeros(N)
stageN = np.zeros(N)
for i,l in enumerate(labels):
    stageCell[i] = int(l[:2])
    stageN[i] = np.log2(stageCell[i]) + 1
    
pt = stageN
# Out:
# Load gene expression

# %%
def plotGene(t,g,labels):
    import matplotlib.cm as cm
    labelLegend = np.unique(labels)
    with plt.style.context('seaborn-whitegrid'):
        colors = cm.spectral(np.linspace(0, 1, len(labelLegend)))
        plt.figure(figsize=(10, 10))
        for lab,c in zip(labelLegend,colors):
            y1 = t[labels == lab]
            y2 = g[labels == lab]
            plt.scatter(y1,y2,label=lab, c=c,s=80)
            plt.text(np.median(y1),np.median(y2),lab, fontsize=45, color='blue')
        plt.legend(loc='upper left')
plotGene(pt, Y, labels)

# %%
from GPclust import OMGP
m = OMGP(pt[:,None], Y, K=2, variance=0.01, prior_Z='DP') # use a truncated DP with K=2
m.rbf.lengthscale = 65
m.rbf_1.lengthscale = 65
m.optimize(step_length=0.01, maxiter=20)
fig=plt.figure(figsize=(10,10))
m.plot()
# Out:
# ('\riteration 1 bound=-19410.1746043 grad=7665.5969511, beta=0',)
# ('\riteration 2 bound=-18553.2485133 grad=23259.5960491, beta=1.82164039737',)
# ('\riteration 3 bound=-11192.069816 grad=153751.326637, beta=2.57856335249',)
# ('\riteration 4 bound=-4372.41478154 grad=652534.103906, beta=1.50473112095',)
# ('\riteration 5 bound=-3741.04030245 grad=95421.7490004, beta=0.0',)
# ('\riteration 6 bound=-3464.31385125 grad=38706.2354019, beta=0.0',)
# ('\riteration 7 bound=-3311.15858739 grad=20691.5608269, beta=0.0',)
# ('\riteration 8 bound=-3208.21370719 grad=14127.5861396, beta=0.0',)
# ('\riteration 9 bound=-3133.99505318 grad=10260.3373873, beta=0.0',)
# ('\riteration 10 bound=-3076.90359751 grad=8880.58833658, beta=0.0',)
# ('\riteration 11 bound=-3032.4302602 grad=7101.7423351, beta=0.0',)
# ('\riteration 12 bound=-2995.36757138 grad=6758.95919831, beta=0.0',)
# ('\riteration 13 bound=-2964.77373641 grad=5652.85848496, beta=0.0',)
# ('\riteration 14 bound=-2936.6163761 grad=5698.96833917, beta=0.0',)
# ('\riteration 15 bound=-2912.13482454 grad=4892.59910548, beta=0.0',)
# ('\riteration 16 bound=-2888.43160872 grad=5292.35118073, beta=0.0',)
# ('\riteration 17 bound=-2867.28853269 grad=4613.11260339, beta=0.0',)
# ('\riteration 18 bound=-2846.5111714 grad=5008.92092515, beta=0.0',)
# ('\riteration 19 bound=-2828.70977044 grad=4275.02098729, beta=0.0',)
# ('\riteration 20 bound=-2811.63211262 grad=4689.15866079, beta=0.0',)
# maxiter exceeded

# %%
m.optimize(step_length=0.01, maxiter=100)
m.plot()
# Out:
# ('\riteration 1 bound=-2797.27690221 grad=3988.49543797, beta=0',)
# ('\riteration 2 bound=-2783.04024112 grad=4345.03184679, beta=0.0',)
# ('\riteration 3 bound=-2771.16514115 grad=3640.32392966, beta=0.0',)
# ('\riteration 4 bound=-2759.00079859 grad=4132.2877447, beta=0.0',)
# ('\riteration 5 bound=-2748.02786774 grad=3586.62632501, beta=0.0',)
# ('\riteration 6 bound=-2735.49254994 grad=4083.61774358, beta=0.0',)
# ('\riteration 7 bound=-2723.46546421 grad=3584.12302354, beta=0.0',)
# ('\riteration 8 bound=-2709.24229578 grad=4240.37766422, beta=0.0',)
# ('\riteration 9 bound=-2694.28500714 grad=3921.64771316, beta=0.0',)
# ('\riteration 10 bound=-2675.89469063 grad=4583.39239736, beta=0.0',)
# ('\riteration 11 bound=-2656.43751494 grad=4286.81986367, beta=0.0',)
# ('\riteration 12 bound=-2633.76933982 grad=5054.1683947, beta=0.0',)
# ('\riteration 13 bound=-2610.39993806 grad=4815.00100932, beta=0.0',)
# ('\riteration 14 bound=-2585.13718893 grad=5361.16173844, beta=0.0',)
# ('\riteration 15 bound=-2562.05669932 grad=4839.88440033, beta=0.0',)
# ('\riteration 16 bound=-2540.46666407 grad=5111.5901715, beta=0.0',)
# ('\riteration 17 bound=-2523.4589744 grad=4366.40201259, beta=0.0',)
# ('\riteration 18 bound=-2509.20072587 grad=4305.64523859, beta=0.0',)
# ('\riteration 19 bound=-2499.9722592 grad=3434.92821536, beta=0.0',)
# ('\riteration 20 bound=-2492.92486941 grad=3490.43605162, beta=0.0',)
# ('\riteration 21 bound=-2489.08126708 grad=2865.0037023, beta=0.0',)
# ('\riteration 22 bound=-2485.56950364 grad=2995.50052291, beta=0.0',)
# ('\riteration 23 bound=-2484.20116882 grad=2473.13245111, beta=0.0',)
# ('\riteration 24 bound=-2482.53520368 grad=2784.16312769, beta=0.0',)
# ('\riteration 25 bound=-2482.06118292 grad=2427.10682232, beta=0.0',)
# ('\riteration 26 bound=-2480.61223862 grad=2699.05817996, beta=0.0',)
# ('\riteration 27 bound=-2480.40851273 grad=2305.99306828, beta=0.0',)
# ('\riteration 28 bound=-2479.44282554 grad=2665.90054474, beta=0.0',)
# ('\riteration 29 bound=-2479.35087239 grad=2361.16187703, beta=0.0',)
# ('\riteration 30 bound=-2478.15911963 grad=2642.9260451, beta=0.0',)
# ('\riteration 31 bound=-2478.09914074 grad=2273.60368062, beta=0.0',)
# ('\riteration 32 bound=-2477.24924919 grad=2631.96494399, beta=0.0',)
# ('\riteration 33 bound=-2477.22373012 grad=2340.66843694, beta=0.0',)
# ('\riteration 34 bound=-2476.10028751 grad=2618.59199741, beta=0.0',)
# ('\riteration 35 bound=-2476.07965703 grad=2258.64401234, beta=0.0',)
# ('\riteration 36 bound=-2475.27811027 grad=2612.64489398, beta=0.0',)
# ('\riteration 38 bound=-2475.28103285 grad=2328.59697984, beta=0.0',)
# ('\riteration 39 bound=-2474.19927078 grad=2602.16924819, beta=0.0',)
# ('\riteration 41 bound=-2474.20439564 grad=2248.46348384, beta=0.0',)
# ('\riteration 42 bound=-2473.44125598 grad=2598.00228066, beta=0.0',)
# ('\riteration 44 bound=-2473.46956727 grad=2319.33618956, beta=0.0',)
# ('\riteration 45 bound=-2472.42751488 grad=2588.65550558, beta=0.0',)
# ('\riteration 47 bound=-2472.4602363 grad=2239.96125099, beta=0.0',)
# ('\riteration 48 bound=-2471.73754114 grad=2585.24754963, beta=0.0',)
# ('\riteration 50 bound=-2471.79545648 grad=2311.12583049, beta=0.0',)
# ('\riteration 51 bound=-490.692744655 grad=16567.9987759, beta=0.0',)
# ('\riteration 52 bound=-478.536954327 grad=1923.58828866, beta=0.393232019434',)
# ('\riteration 53 bound=-463.637356023 grad=1763.01660773, beta=0.0',)
# ('\riteration 54 bound=-450.471088612 grad=947.399348454, beta=0.665298563966',)
# ('\riteration 55 bound=-445.246329629 grad=309.644908552, beta=0.390878975416',)
# ('\riteration 56 bound=-442.675060224 grad=173.239383174, beta=0.268669257701',)
# ('\riteration 57 bound=-439.90869458 grad=132.534895375, beta=0.71379387511',)
# ('\riteration 58 bound=-437.489457892 grad=90.9793263423, beta=0.702140785007',)
# ('\riteration 59 bound=-435.671399152 grad=59.939190666, beta=0.656595927306',)
# ('\riteration 60 bound=-434.363211742 grad=40.2026563654, beta=0.64799463371',)
# ('\riteration 61 bound=-433.434251579 grad=27.8175566796, beta=0.638005628346',)
# ('\riteration 62 bound=-432.759984417 grad=20.1253224065, beta=0.639110401708',)
# ('\riteration 63 bound=-432.244579868 grad=15.0414125297, beta=0.666373039197',)
# ('\riteration 64 bound=-431.840715316 grad=11.3638452022, beta=0.685524882042',)
# ('\riteration 65 bound=-431.520616519 grad=8.58892751905, beta=0.702499043228',)
# ('\riteration 66 bound=-431.269619005 grad=6.4675793976, beta=0.703358100957',)
# ('\riteration 67 bound=-431.075483704 grad=4.90970353509, beta=0.694636767317',)
# ('\riteration 68 bound=-430.921654201 grad=3.78004307994, beta=0.714207374398',)
# ('\riteration 69 bound=-430.797976144 grad=2.90328219499, beta=0.734238587543',)
# ('\riteration 70 bound=-430.701441503 grad=2.22307601931, beta=0.716011991127',)
# ('\riteration 71 bound=-430.625915868 grad=1.73169311073, beta=0.714653045',)
# ('\riteration 72 bound=-430.564062874 grad=1.35856897061, beta=0.755795988387',)
# ('\riteration 73 bound=-430.514015155 grad=1.04808146951, beta=0.759454950017',)
# ('\riteration 74 bound=-430.475178426 grad=0.804733411897, beta=0.731106367739',)
# ('\riteration 75 bound=-430.44456879 grad=0.626429751005, beta=0.74283133167',)
# ('\riteration 76 bound=-430.419760026 grad=0.485828024394, beta=0.77331850135',)
# ('\riteration 77 bound=-430.400194034 grad=0.370059261891, beta=0.762269228495',)
# ('\riteration 78 bound=-430.385165027 grad=0.280955507199, beta=0.745788925677',)
# ('\riteration 79 bound=-430.373502082 grad=0.214162190646, beta=0.757258713414',)
# ('\riteration 80 bound=-430.364458187 grad=0.162144509636, beta=0.763400925627',)
# ('\riteration 81 bound=-430.357563812 grad=0.121760615575, beta=0.755961961933',)
# ('\riteration 82 bound=-430.352343122 grad=0.0911194761908, beta=0.754772472042',)
# ('\riteration 83 bound=-430.348425306 grad=0.0680334308161, beta=0.749371768292',)
# ('\riteration 84 bound=-430.345501058 grad=0.0510188187833, beta=0.743156818239',)
# ('\riteration 85 bound=-430.343280681 grad=0.0384231041695, beta=0.756200918188',)
# ('\riteration 86 bound=-430.341598742 grad=0.0287195181035, beta=0.758032618126',)
# ('\riteration 87 bound=-430.340360344 grad=0.0214584473039, beta=0.735356416695',)
# ('\riteration 88 bound=-430.339438145 grad=0.0163064129675, beta=0.739137406894',)
# ('\riteration 89 bound=-430.338726875 grad=0.0124345646459, beta=0.767503410459',)
# ('\riteration 90 bound=-430.338187352 grad=0.00936464899721, beta=0.756508850878',)
# ('\riteration 91 bound=-430.337787106 grad=0.00709454739772, beta=0.732133114361',)
# ('\riteration 92 bound=-430.337480062 grad=0.0054730125195, beta=0.750034587161',)
# ('\riteration 93 bound=-430.337239441 grad=0.00422016174808, beta=0.768090315857',)
# ('\riteration 94 bound=-430.337056005 grad=0.00324267483033, beta=0.747859640043',)
# ('\riteration 95 bound=-430.336917233 grad=0.00253258706743, beta=0.736132872929',)
# ('\riteration 96 bound=-430.33680878 grad=0.00201639225674, beta=0.752903223106',)
# ('\riteration 97 bound=-430.336722225 grad=0.00162000206828, beta=0.760288506032',)
# ('\riteration 98 bound=-430.336652388 grad=0.00131362711365, beta=0.757846449026',)
# ('\riteration 99 bound=-430.33659502 grad=0.00107783425966, beta=0.763138265247',)
# ('\riteration 100 bound=-430.336547331 grad=0.000893380421908, beta=0.769486997544',)
# maxiter exceeded

# %%
m.plot_probs()

# %%
m
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: OMGP<br>
# <b>Objective</b>: 430.336547331<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  OMGP.            </b></th><th><b>          value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  variance         </td><td class=tg-right>0.0540319404468</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.variance     </td><td class=tg-right>  27.1768563586</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale  </td><td class=tg-right>  63.3313367451</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf_1.variance   </td><td class=tg-right>  25.2085878734</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf_1.lengthscale</td><td class=tg-right>  63.5180517666</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# # VB Branching code

# %%
import BranchingTree as bt
import branch_kernParamGPflow as bk
def InitModels(pt, XExpanded, Y):
    # code that's a bit crappy - we dont need this
    tree = bt.BinaryBranchingTree(0,90,fDebug=False) # set to true to print debug messages
    tree.add(None,1,10) # single branching point
    (fm, _) = tree.GetFunctionBranchTensor()
    #KbranchVB = bk.BranchKernelParam(GPflow.kernels.RBF(1), fm, BvInitial=np.ones((1,1))) + GPflow.kernels.White(1) 
    KbranchVB = bk.BranchKernelParam(GPflow.kernels.RBF(1), fm, BvInitial=np.ones((1,1))) + GPflow.kernels.White(1) + GPflow.kernels.Linear(1) + GPflow.kernels.Constant(1) # other copy of kernel
    KbranchVB.branchkernelparam.Bv.fixed = True
    mV = assigngp_dense.AssignGP(pt, XExpanded, Y, KbranchVB)
    mV.kern.white.variance = 1e-6
    mV.kern.white.variance.fixed = True
    mV._compile() # creates objective function
    return mV

# %%
phiInitial, phiInitial_invSoftmax, XExpanded = VBHelperFunctions.InitialisePhiFromOMGP(None, phiOMGP=m.phi, b=0, Y=Y,pt=pt)   
mV = InitModels(pt,XExpanded,Y) # also do gene by gene
# Out:
# compiling tensorflow function...
# done

# %%
mV
# Out:
# <table id='parms' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constriant</td></tr><tr><td>model.likelihood.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.linear.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.constant.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.white.variance</td><td>[  1.00000000e-06]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.branchkernelparam.Bv</td><td>[[ 1.]]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.branchkernelparam.kern.lengthscales</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.branchkernelparam.kern.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.logPhi</td><td>[[ -2.92829526e+00  -3.10224741e-01   5.32952874e-01 ...,   5.77130869e-02</br>   -9.40559103e-01   2.16295224e+00]</br> [ -6.25285954e-01   2.27844636e+00   5.28733079e-01 ...,   3.34013101e-01</br>   -6.39573101e-01  -1.37894746e+00]</br> [  1.11147997e+00  -2.12825372e+00   2.21662605e-01 ...,  -1.21706888e+00</br>   -2.84951987e-01   8.02222268e-01]</br> ..., </br> [  8.69055583e-02  -9.96534924e-01   1.70743505e-03 ...,  -7.83228918e-01</br>   -6.32121582e-01   4.15701268e-01]</br> [ -4.50536649e-01  -3.86697414e-01  -1.21817734e+00 ...,   2.13815258e-01</br>    1.74362071e+00   2.74957134e-01]</br> [ -1.07222889e+00  -2.81461701e+00   1.14458149e+00 ...,   1.37540156e+00</br>    3.18949510e-02  -1.75398607e-01]]</td><td>None</td><td>(none)</td></tr></table>

# %%
m
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: OMGP<br>
# <b>Objective</b>: 430.336547331<br>
# <b>Number of Parameters</b>: 5<br>
# <b>Number of Optimization Parameters</b>: 5<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  OMGP.            </b></th><th><b>          value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  variance         </td><td class=tg-right>0.0540319404468</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.variance     </td><td class=tg-right>  27.1768563586</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale  </td><td class=tg-right>  63.3313367451</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf_1.variance   </td><td class=tg-right>  25.2085878734</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf_1.lengthscale</td><td class=tg-right>  63.5180517666</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
# Initialise all model parameters using the OMGP model
# Note that the OMGP model has different kernel hyperparameters for each latent function whereas the branching model
# has one common set.
mV.logPhi = phiInitial_invSoftmax # initialise allocations from OMGP
mV.likelihood.variance = m.variance.values[0]
# set lengthscale to maximum
mV.kern.branchkernelparam.kern.lengthscales = np.max(np.array([m.rbf.lengthscale.values, m.rbf_1.lengthscale.values]))
# set process variance to average
mV.kern.branchkernelparam.kern.variance = np.mean(np.array([m.rbf.variance.values, m.rbf_1.variance.values]))
mV
# Out:
# <table id='parms' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constriant</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.05403194]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.linear.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.constant.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.white.variance</td><td>[  1.00000000e-06]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.branchkernelparam.Bv</td><td>[[ 1.]]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.branchkernelparam.kern.lengthscales</td><td>[ 63.51805177]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.branchkernelparam.kern.variance</td><td>[ 26.19272212]</td><td>None</td><td>+ve</td></tr><tr><td>model.logPhi</td><td>[[ -2.76310211e+01  -2.45772542e+00  -8.95194294e-02 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> ..., </br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -2.76310211e+01</br>   -4.15069013e+00  -1.58789466e-02]]</td><td>None</td><td>(none)</td></tr></table>

# %%
def FlattenPhi(mV):
    # return flattened and rounded Phi i.e. N X 3
    phiFlattened = np.zeros((mV.Y.shape[0],3)) # only single branching point
    Phi = np.round(np.exp(mV.logPhi._array),decimals=4)
    f=2 # which function to plot phi against - can be 1,2 or 3
    iterC=0
    for i,p in enumerate(mV.t):
        phiFlattened[i,:] = Phi[i,iterC:iterC+3] 
        iterC+=3
    return phiFlattened
Phi=FlattenPhi(mV)

# %%
def plotVBCode(mV,figsizeIn=(20,10),lw=3.,fs=10):
    from matplotlib import cm
    D = mV.Y.shape[0]
    fig=plt.figure(figsize=figsizeIn)
    B=mV.kern.branchkernelparam.Bv._array.flatten()
    assert B.size == 1, 'Code limited to one branch point, got ' + str(B.shape)
    pt = mV.t
    l = np.min(pt)
    u = np.max(pt)
    d = 0 # constraint code to be 1D for now
    for f in range(1, 4):
        if(f == 1):
            ttest = np.linspace(l, B, 100)[:, None]  # root
        else:
            ttest = np.linspace(B, u, 100)[:, None]
        Xtest = np.hstack((ttest, ttest*0+f))
        mu, var = mV.predict_f(Xtest)
        assert np.all(np.isfinite(mu)), 'All elements should be finite but are ' + str(mu)
        assert np.all(np.isfinite(var)), 'All elements should be finite but are ' + str(var)
        mean, = plt.plot(ttest, mu[:, d], linewidth=lw)
        col = mean.get_color()
        plt.plot(ttest.flatten(), mu[:, d] + 2*np.sqrt(var.flatten()), '--', color=col, linewidth=lw)
        plt.plot(ttest, mu[:, d] - 2*np.sqrt(var.flatten()), '--', color=col, linewidth=lw)

    v = plt.axis()
    plt.plot([B, B], v[-2:], '-m',linewidth=lw)
    
    # could also plot phi
    Phi=FlattenPhi(mV)
    gp_num = 1 # can be 0,1,2 
    plt.scatter(pt, mV.Y[:,d], c=Phi[:, gp_num], vmin=0., vmax=1, s=40)
    plt.colorbar(label='GP {} assignment probability'.format(gp_num))

# %% [markdown]
# # Bayesian optimisation
# 1. Use GPyOpt to learn branching point and kernel hyperparameters.
# 1. set fixed=False for all parameters except for Phi.fixed=True
# 1. It's still beneficial to use *VB code* rather than *Jings model* since we integrate out (approximately using VB bound) uncertainty in allocation (Phi).
# 1. Store all intermediate values visited by GPyOpt?
# 1. Use Matern 3/2 or 5/2 for both OMGP and our model. Actually different kernels for OMGP and our can make sense as outputs different (potentially)?
# 1. Effect of Phi on inference of branching point?
# 1. add assert in VB code that before branching point, allocations probs==1 for 1st function.

# %%
import GPyOpt

# %%
# Objective function
class objectiveBAndK:
    def __init__(self, Binit):
        mV.kern.branchkernelparam.Bv.fixed = False # we wont optimize so this is fine
        mV.logPhi.fixed = False # allocations not fixed for GPyOpt because we update them for each branch point

        mV.likelihood.variance.fixed = False # all kernel parameters optimised
        mV.kern.branchkernelparam.kern.lengthscales.fixed = False
        mV.kern.branchkernelparam.kern.variance.fixed = False

        # initial branch point
        mV.kern.branchkernelparam.Bv = Binit
        VBHelperFunctions.InitialisePhiFromOMGP(mV, phiOMGP=m.phi, b=Binit, Y=Y, pt=pt)  
        # Initialise all model parameters using the OMGP model 
        mV.likelihood.variance = m.variance.values[0]
        mV.kern.branchkernelparam.kern.lengthscales = np.max(np.array([m.rbf.lengthscale.values, m.rbf_1.lengthscale.values]))
        mV.kern.branchkernelparam.kern.variance = np.mean(np.array([m.rbf.variance.values, m.rbf_1.variance.values]))
        mV._compile()

    def f(self, theta):
        # theta is nxp array, return nx1
        n=theta.shape[0]
        VBboundarray = np.ones((n,1))
        for i in range(n):
            mV.kern.branchkernelparam.Bv = theta[i,0]
            VBHelperFunctions.InitialisePhiFromOMGP(mV, phiOMGP=m.phi, b=theta[i,0], Y=Y, pt=pt)  
            mV.likelihood.variance = theta[i,1]
            mV.kern.branchkernelparam.kern.lengthscales = theta[i,2]
            mV.kern.branchkernelparam.kern.variance = theta[i,3]
            mV.kern.linear.variance = theta[i,4]
            mV.kern.constant.variance = theta[i,5]
            
            VBboundarray[i] = -mV.compute_log_likelihood() # we wish to minimize!
            print 'objectiveB B=%.0f likvar=%.0f len=%.0f var=%.0f linvar=%.0f constvar=%.0f VB=%.0f'\
            %(theta[i,0], theta[i,1], theta[i,2], theta[i,3], theta[i,4],theta[i,5],VBboundarray[i] )
        return VBboundarray

# %%
# try optimisation
l = pt.min() + 1
u = pt.max() - 1
print l,u
# We need constraints on there parameters
# B = [l,u] 
# lik.variance > 0
# kern.lengthscale, variance > 0

# --- Optimize both B and K
myobj = objectiveBAndK(np.ones((1,1))*(l+u)/2) # pass in initial point - start at mid-point
eps = 1e-5
#bounds = [(l,u),(eps,3*Y.var()), (eps,pt.max()), (eps,3*Y.var())]  # B, lik var, len, var

bounds = [(l,u),(eps,3*Y.var()), (eps+2,pt.max()), (eps,3*Y.var()), [0.1,5], [4,10]]  # B, lik var, len, var, lin var, c var

BOobj = GPyOpt.methods.BayesianOptimization(f=myobj.f,  # function to optimize       
                                            bounds=bounds)              # normalized y                       
t0=time.time()
max_iter = 20 
import multiprocessing
n_cores = multiprocessing.cpu_count()

BOobj.run_optimization(max_iter,                             # Number of iterations
                       acqu_optimize_method = 'fast_random',        # method to optimize the acq. function
                       acqu_optimize_restarts = 30,
                       batch_method='lp',
                       n_inbatch = n_cores,                        # size of the collected batches (= number of cores)
                       eps = 1e-6)                                # secondary stop criteria (apart from the number of iterations) 

print 'GPyOpt took %g secs ' %(time.time()-t0)
# Out:
# 2.0 6.0
# compiling tensorflow function...
# done
# objectiveB B=5 likvar=3 len=5 var=1 linvar=0 constvar=8 VB=1085
# objectiveB B=4 likvar=2 len=7 var=1 linvar=4 constvar=7 VB=1020
# objectiveB B=5 likvar=0 len=3 var=3 linvar=5 constvar=4 VB=877
# objectiveB B=5 likvar=2 len=7 var=0 linvar=2 constvar=4 VB=1071
# objectiveB B=3 likvar=1 len=4 var=3 linvar=3 constvar=9 VB=887
# objectiveB B=5 likvar=3 len=4 var=1 linvar=2 constvar=8 VB=1059
# objectiveB B=5 likvar=3 len=3 var=1 linvar=0 constvar=7 VB=1046
# objectiveB B=5 likvar=1 len=4 var=1 linvar=2 constvar=10 VB=890
# objectiveB B=5 likvar=0 len=7 var=1 linvar=3 constvar=7 VB=2163
# objectiveB B=6 likvar=0 len=4 var=3 linvar=0 constvar=7 VB=903
# objectiveB B=6 likvar=1 len=3 var=0 linvar=1 constvar=7 VB=973
# objectiveB B=5 likvar=1 len=4 var=2 linvar=2 constvar=7 VB=896
# objectiveB B=2 likvar=1 len=2 var=1 linvar=5 constvar=8 VB=900
# objectiveB B=2 likvar=2 len=6 var=1 linvar=4 constvar=6 VB=1010
# objectiveB B=2 likvar=3 len=6 var=0 linvar=3 constvar=10 VB=1123
# objectiveB B=2 likvar=2 len=6 var=1 linvar=5 constvar=6 VB=1052
# objectiveB B=2 likvar=1 len=5 var=2 linvar=5 constvar=6 VB=947
# objectiveB B=6 likvar=1 len=4 var=1 linvar=3 constvar=7 VB=918
# objectiveB B=3 likvar=3 len=2 var=3 linvar=2 constvar=10 VB=1079
# objectiveB B=3 likvar=0 len=3 var=2 linvar=1 constvar=4 VB=2006
# objectiveB B=5 likvar=1 len=5 var=3 linvar=4 constvar=4 VB=902
# objectiveB B=2 likvar=2 len=7 var=0 linvar=2 constvar=8 VB=1005
# objectiveB B=5 likvar=2 len=2 var=0 linvar=5 constvar=7 VB=984
# objectiveB B=6 likvar=2 len=3 var=1 linvar=0 constvar=10 VB=980
# objectiveB B=6 likvar=1 len=3 var=3 linvar=0 constvar=4 VB=927
# objectiveB B=2 likvar=1 len=6 var=1 linvar=5 constvar=7 VB=878
# objectiveB B=3 likvar=1 len=3 var=2 linvar=4 constvar=10 VB=900
# objectiveB B=5 likvar=3 len=6 var=0 linvar=4 constvar=5 VB=1098
# objectiveB B=6 likvar=2 len=3 var=1 linvar=0 constvar=8 VB=1027
# objectiveB B=2 likvar=1 len=6 var=3 linvar=0 constvar=9 VB=968
# objectiveB B=5 likvar=1 len=3 var=3 linvar=5 constvar=4 VB=872
# objectiveB B=6 likvar=1 len=7 var=3 linvar=0 constvar=5 VB=965
# objectiveB B=2 likvar=1 len=2 var=0 linvar=5 constvar=9 VB=952
# objectiveB B=2 likvar=0 len=7 var=2 linvar=0 constvar=5 VB=2156
# objectiveB B=2 likvar=2 len=3 var=0 linvar=5 constvar=10 VB=1016
# objectiveB B=6 likvar=0 len=7 var=0 linvar=4 constvar=10 VB=1032
# objectiveB B=5 likvar=2 len=3 var=3 linvar=1 constvar=5 VB=958
# objectiveB B=4 likvar=2 len=2 var=2 linvar=5 constvar=5 VB=996
# objectiveB B=3 likvar=2 len=2 var=3 linvar=0 constvar=9 VB=1035
# objectiveB B=5 likvar=1 len=7 var=3 linvar=2 constvar=5 VB=899
# objectiveB B=6 likvar=1 len=2 var=1 linvar=3 constvar=10 VB=925
# objectiveB B=2 likvar=2 len=6 var=1 linvar=4 constvar=4 VB=1027
# objectiveB B=5 likvar=3 len=2 var=2 linvar=4 constvar=8 VB=1049
# objectiveB B=5 likvar=2 len=6 var=1 linvar=4 constvar=4 VB=983
# objectiveB B=6 likvar=2 len=4 var=2 linvar=1 constvar=10 VB=1019
# objectiveB B=4 likvar=2 len=7 var=1 linvar=5 constvar=10 VB=1033
# objectiveB B=3 likvar=0 len=2 var=1 linvar=1 constvar=7 VB=854
# objectiveB B=3 likvar=0 len=6 var=1 linvar=1 constvar=4 VB=2073
# objectiveB B=3 likvar=0 len=3 var=0 linvar=4 constvar=9 VB=857
# objectiveB B=4 likvar=0 len=7 var=3 linvar=1 constvar=10 VB=1007
# objectiveB B=5 likvar=2 len=2 var=1 linvar=4 constvar=9 VB=965
# objectiveB B=2 likvar=3 len=5 var=1 linvar=2 constvar=10 VB=1102
# objectiveB B=5 likvar=3 len=3 var=3 linvar=5 constvar=4 VB=1077
# objectiveB B=5 likvar=1 len=6 var=3 linvar=5 constvar=5 VB=950
# objectiveB B=2 likvar=2 len=5 var=1 linvar=0 constvar=10 VB=999
# objectiveB B=5 likvar=0 len=3 var=2 linvar=0 constvar=4 VB=921
# objectiveB B=5 likvar=1 len=2 var=1 linvar=5 constvar=9 VB=947
# objectiveB B=4 likvar=0 len=7 var=2 linvar=5 constvar=4 VB=895
# objectiveB B=5 likvar=2 len=2 var=1 linvar=4 constvar=9 VB=1014
# objectiveB B=4 likvar=1 len=2 var=3 linvar=4 constvar=4 VB=957
# objectiveB B=5 likvar=1 len=6 var=2 linvar=1 constvar=10 VB=958
# objectiveB B=2 likvar=1 len=6 var=1 linvar=2 constvar=4 VB=863
# objectiveB B=5 likvar=1 len=6 var=2 linvar=5 constvar=9 VB=886
# objectiveB B=5 likvar=2 len=6 var=0 linvar=0 constvar=10 VB=1023
# objectiveB B=6 likvar=2 len=7 var=2 linvar=4 constvar=4 VB=1023
# objectiveB B=3 likvar=1 len=2 var=1 linvar=1 constvar=10 VB=933
# objectiveB B=6 likvar=1 len=2 var=3 linvar=4 constvar=8 VB=935
# objectiveB B=2 likvar=2 len=7 var=2 linvar=3 constvar=9 VB=1054
# objectiveB B=6 likvar=3 len=6 var=0 linvar=1 constvar=10 VB=1070
# objectiveB B=2 likvar=0 len=3 var=2 linvar=4 constvar=4 VB=855
# objectiveB B=6 likvar=2 len=2 var=0 linvar=4 constvar=9 VB=1032
# objectiveB B=3 likvar=0 len=2 var=2 linvar=1 constvar=4 VB=1111
# objectiveB B=3 likvar=2 len=7 var=1 linvar=4 constvar=9 VB=1051
# objectiveB B=4 likvar=1 len=7 var=1 linvar=2 constvar=4 VB=910
# objectiveB B=6 likvar=2 len=6 var=1 linvar=4 constvar=10 VB=1014
# objectiveB B=5 likvar=2 len=2 var=3 linvar=5 constvar=9 VB=993
# objectiveB B=3 likvar=0 len=5 var=2 linvar=5 constvar=4 VB=1879
# objectiveB B=3 likvar=1 len=2 var=0 linvar=1 constvar=4 VB=926
# objectiveB B=5 likvar=1 len=2 var=1 linvar=0 constvar=10 VB=907
# objectiveB B=5 likvar=3 len=7 var=2 linvar=5 constvar=5 VB=1053
# objectiveB B=5 likvar=1 len=7 var=0 linvar=0 constvar=4 VB=932
# objectiveB B=3 likvar=3 len=6 var=3 linvar=0 constvar=9 VB=1086
# objectiveB B=5 likvar=3 len=2 var=2 linvar=2 constvar=9 VB=1054
# objectiveB B=6 likvar=2 len=3 var=1 linvar=5 constvar=6 VB=992
# objectiveB B=2 likvar=0 len=7 var=1 linvar=4 constvar=9 VB=8248
# objectiveB B=6 likvar=0 len=5 var=0 linvar=1 constvar=5 VB=1063
# objectiveB B=5 likvar=2 len=2 var=0 linvar=5 constvar=9 VB=1043
# objectiveB B=2 likvar=1 len=6 var=1 linvar=5 constvar=4 VB=949
# objectiveB B=4 likvar=3 len=6 var=3 linvar=2 constvar=5 VB=1092
# objectiveB B=4 likvar=3 len=7 var=2 linvar=1 constvar=10 VB=1086
# objectiveB B=5 likvar=3 len=3 var=1 linvar=0 constvar=7 VB=1049
# objectiveB B=5 likvar=0 len=2 var=1 linvar=4 constvar=9 VB=864
# objectiveB B=3 likvar=2 len=2 var=0 linvar=2 constvar=4 VB=1080
# objectiveB B=6 likvar=2 len=7 var=2 linvar=1 constvar=10 VB=1021
# objectiveB B=2 likvar=2 len=5 var=2 linvar=1 constvar=4 VB=1043
# objectiveB B=5 likvar=2 len=6 var=2 linvar=5 constvar=5 VB=971
# objectiveB B=3 likvar=0 len=2 var=3 linvar=1 constvar=9 VB=860
# objectiveB B=3 likvar=1 len=6 var=2 linvar=5 constvar=4 VB=878
# objectiveB B=5 likvar=3 len=3 var=2 linvar=2 constvar=7 VB=1081
# objectiveB B=3 likvar=1 len=3 var=2 linvar=1 constvar=4 VB=877
# objectiveB B=5 likvar=1 len=2 var=0 linvar=4 constvar=9 VB=954
# objectiveB B=5 likvar=1 len=7 var=2 linvar=1 constvar=9 VB=938
# objectiveB B=5 likvar=1 len=5 var=1 linvar=4 constvar=5 VB=904
# objectiveB B=3 likvar=3 len=7 var=2 linvar=1 constvar=5 VB=1073
# objectiveB B=6 likvar=3 len=3 var=1 linvar=4 constvar=9 VB=1057
# objectiveB B=2 likvar=3 len=2 var=2 linvar=4 constvar=9 VB=1089
# objectiveB B=6 likvar=1 len=2 var=1 linvar=4 constvar=4 VB=961
# objectiveB B=5 likvar=2 len=4 var=3 linvar=0 constvar=5 VB=1030
# objectiveB B=3 likvar=0 len=3 var=2 linvar=4 constvar=9 VB=849
# objectiveB B=6 likvar=1 len=7 var=2 linvar=0 constvar=4 VB=936
# objectiveB B=2 likvar=2 len=2 var=1 linvar=3 constvar=4 VB=1073
# objectiveB B=3 likvar=3 len=3 var=2 linvar=4 constvar=10 VB=1098
# objectiveB B=4 likvar=1 len=7 var=2 linvar=4 constvar=10 VB=978
# objectiveB B=2 likvar=3 len=7 var=1 linvar=5 constvar=4 VB=1093
# objectiveB B=5 likvar=3 len=2 var=1 linvar=3 constvar=5 VB=1071
# objectiveB B=6 likvar=3 len=4 var=2 linvar=4 constvar=9 VB=1064
# objectiveB B=4 likvar=2 len=2 var=2 linvar=0 constvar=9 VB=1045
# objectiveB B=5 likvar=0 len=6 var=1 linvar=0 constvar=5 VB=934
# objectiveB B=3 likvar=2 len=7 var=0 linvar=4 constvar=10 VB=1082
# objectiveB B=2 likvar=1 len=2 var=2 linvar=1 constvar=5 VB=903
# objectiveB B=6 likvar=0 len=2 var=0 linvar=4 constvar=10 VB=927
# objectiveB B=6 likvar=3 len=7 var=2 linvar=0 constvar=4 VB=1061
# objectiveB B=6 likvar=1 len=2 var=3 linvar=5 constvar=5 VB=952
# objectiveB B=2 likvar=0 len=2 var=2 linvar=1 constvar=10 VB=863
# objectiveB B=6 likvar=3 len=2 var=0 linvar=2 constvar=10 VB=1059
# objectiveB B=3 likvar=3 len=2 var=3 linvar=2 constvar=4 VB=1103
# objectiveB B=5 likvar=1 len=7 var=1 linvar=2 constvar=4 VB=928
# objectiveB B=5 likvar=1 len=7 var=3 linvar=1 constvar=10 VB=899
# objectiveB B=3 likvar=1 len=7 var=1 linvar=4 constvar=4 VB=978
# objectiveB B=3 likvar=3 len=2 var=2 linvar=4 constvar=10 VB=1079
# objectiveB B=6 likvar=2 len=2 var=2 linvar=0 constvar=5 VB=1007
# objectiveB B=6 likvar=2 len=5 var=0 linvar=4 constvar=9 VB=1024
# objectiveB B=3 likvar=2 len=2 var=3 linvar=0 constvar=10 VB=1058
# objectiveB B=5 likvar=3 len=6 var=1 linvar=5 constvar=4 VB=1063
# objectiveB B=6 likvar=3 len=6 var=2 linvar=1 constvar=4 VB=1072
# objectiveB B=2 likvar=3 len=2 var=3 linvar=0 constvar=4 VB=1106
# objectiveB B=5 likvar=2 len=2 var=2 linvar=4 constvar=10 VB=1002
# objectiveB B=5 likvar=2 len=3 var=1 linvar=5 constvar=4 VB=1008
# objectiveB B=3 likvar=2 len=2 var=3 linvar=0 constvar=7 VB=1045
# objectiveB B=5 likvar=1 len=5 var=2 linvar=3 constvar=4 VB=894
# objectiveB B=6 likvar=3 len=5 var=1 linvar=4 constvar=10 VB=1069
# objectiveB B=3 likvar=2 len=2 var=2 linvar=1 constvar=4 VB=1070
# objectiveB B=2 likvar=3 len=3 var=0 linvar=1 constvar=10 VB=1092
# objectiveB B=5 likvar=1 len=2 var=1 linvar=4 constvar=5 VB=892
# objectiveB B=2 likvar=0 len=7 var=0 linvar=4 constvar=10 VB=938
# objectiveB B=3 likvar=2 len=6 var=0 linvar=0 constvar=4 VB=1065
# objectiveB B=6 likvar=3 len=4 var=3 linvar=4 constvar=5 VB=1063
# objectiveB B=6 likvar=2 len=2 var=1 linvar=2 constvar=8 VB=1016
# objectiveB B=2 likvar=2 len=2 var=1 linvar=0 constvar=7 VB=1059
# objectiveB B=2 likvar=0 len=7 var=1 linvar=4 constvar=8 VB=866
# objectiveB B=5 likvar=3 len=6 var=3 linvar=0 constvar=10 VB=1066
# objectiveB B=2 likvar=3 len=2 var=1 linvar=5 constvar=4 VB=1087
# objectiveB B=6 likvar=0 len=3 var=2 linvar=0 constvar=10 VB=999
# objectiveB B=5 likvar=1 len=6 var=2 linvar=0 constvar=5 VB=921
# objectiveB B=6 likvar=2 len=2 var=0 linvar=0 constvar=4 VB=1035
# objectiveB B=4 likvar=1 len=2 var=3 linvar=1 constvar=9 VB=978
# objectiveB B=5 likvar=2 len=4 var=0 linvar=5 constvar=10 VB=1051
# objectiveB B=4 likvar=2 len=7 var=1 linvar=4 constvar=4 VB=1025
# objectiveB B=3 likvar=0 len=7 var=2 linvar=0 constvar=5 VB=862
# objectiveB B=3 likvar=2 len=2 var=0 linvar=0 constvar=10 VB=1027
# objectiveB B=6 likvar=2 len=2 var=3 linvar=3 constvar=4 VB=980
# objectiveB B=6 likvar=3 len=7 var=1 linvar=4 constvar=10 VB=1076
# objectiveB B=5 likvar=3 len=3 var=2 linvar=1 constvar=6 VB=1084
# objectiveB B=6 likvar=2 len=2 var=2 linvar=5 constvar=5 VB=1020
# objectiveB B=5 likvar=0 len=6 var=2 linvar=1 constvar=10 VB=927
# objectiveB B=2 likvar=2 len=2 var=0 linvar=1 constvar=5 VB=1040
# objectiveB B=4 likvar=1 len=6 var=2 linvar=1 constvar=4 VB=881
# objectiveB B=6 likvar=3 len=2 var=0 linvar=1 constvar=10 VB=1060
# objectiveB B=5 likvar=1 len=2 var=2 linvar=5 constvar=10 VB=917
# objectiveB B=2 likvar=2 len=6 var=1 linvar=5 constvar=9 VB=1071
# objectiveB B=6 likvar=1 len=3 var=1 linvar=4 constvar=4 VB=965
# objectiveB B=5 likvar=3 len=3 var=3 linvar=1 constvar=8 VB=1033
# objectiveB B=2 likvar=2 len=2 var=0 linvar=1 constvar=4 VB=1064
# objectiveB B=6 likvar=3 len=6 var=1 linvar=5 constvar=10 VB=1080
# objectiveB B=6 likvar=2 len=7 var=2 linvar=4 constvar=4 VB=1040
# objectiveB B=2 likvar=3 len=2 var=2 linvar=1 constvar=9 VB=1093
# objectiveB B=3 likvar=0 len=2 var=3 linvar=5 constvar=5 VB=1134
# objectiveB B=3 likvar=1 len=6 var=2 linvar=1 constvar=9 VB=974
# *Optimization completed:
#    -Maximum number of iterations reached.
# GPyOpt took 152.133 secs

# %%
print 'Solution found by BO'
print BOobj.x_opt
print BOobj.fx_opt

# Can explicitly check computation using myobj.f(np.ones((1,1))*16.834)
# should add assert that Phi before branching point is 1 everywhere!
# Out:
# Solution found by BO
# [ 3.09583718  0.35146725  2.69714807  1.58985697  4.19823409  9.2432377 ]
# [ 848.8128611]

# %%
def plotVBCode(mV,figsizeIn=(20,10),lw=3.,fs=10,labels=None, fPlotPhi=True, fPlotVar=True):
    import matplotlib.cm as cm
    from matplotlib import cm
    D = mV.Y.shape[0]
    fig=plt.figure(figsize=figsizeIn)
    B=mV.kern.branchkernelparam.Bv._array.flatten()
    assert B.size == 1, 'Code limited to one branch point, got ' + str(B.shape)
    pt = mV.t
    l = np.min(pt)
    u = np.max(pt)
    d = 0 # constraint code to be 1D for now
    for f in range(1, 4):
        if(f == 1):
            ttest = np.linspace(l, B, 100)[:, None]  # root
        else:
            ttest = np.linspace(B, u, 100)[:, None]
        Xtest = np.hstack((ttest, ttest*0+f))
        mu, var = mV.predict_f(Xtest)
        assert np.all(np.isfinite(mu)), 'All elements should be finite but are ' + str(mu)
        assert np.all(np.isfinite(var)), 'All elements should be finite but are ' + str(var)
        mean, = plt.plot(ttest, mu[:, d], linewidth=lw)
        col = mean.get_color()
        if(fPlotVar):
            plt.plot(ttest.flatten(), mu[:, d] + 2*np.sqrt(var.flatten()), '--', color=col, linewidth=lw)
            plt.plot(ttest, mu[:, d] - 2*np.sqrt(var.flatten()), '--', color=col, linewidth=lw)

    v = plt.axis()
    plt.plot([B, B], v[-2:], '-m',linewidth=lw)
    
    # Plot Phi or labels
    if(fPlotPhi):
        Phi=FlattenPhi(mV)
        gp_num = 1 # can be 0,1,2 
        plt.scatter(pt, mV.Y[:,d], c=Phi[:, gp_num], vmin=0., vmax=1, s=40)
        plt.colorbar(label='GP {} assignment probability'.format(gp_num))
    elif(labels is not None):
        # plot labels
        labelLegend = np.unique(labels)
        with plt.style.context('seaborn-whitegrid'):
            colors = cm.spectral(np.linspace(0, 1, len(labelLegend)))
            for lab,c in zip(labelLegend,colors):
                y1 = pt[labels == lab]
                y2 = Y[labels == lab]
                plt.scatter(y1,y2,label=lab, c=c,s=80)
                plt.text(np.median(y1),np.median(y2),lab, fontsize=45, color='blue')
            plt.legend(loc='upper left')

# %%
# plot best solution
mV.kern.branchkernelparam.Bv = BOobj.x_opt[0]
VBHelperFunctions.InitialisePhiFromOMGP(mV, phiOMGP=m.phi, b=BOobj.x_opt[0],Y=Y,pt=pt)   
mV.likelihood.variance = BOobj.x_opt[1]
mV.kern.branchkernelparam.kern.lengthscales = BOobj.x_opt[2]
mV.kern.branchkernelparam.kern.variance = BOobj.x_opt[3]
print 'Bound got %.2f should be %.2f'%(-mV.compute_log_likelihood(), BOobj.fx_opt)
plotVBCode(mV,fPlotVar=False)
# Out:
# Bound got 847.96 should be 848.81

# %%
plotVBCode(mV,labels=labels,fPlotPhi=False,fPlotVar=False)

# %%
mV
# Out:
# <table id='parms' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constriant</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.35146725]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.linear.variance</td><td>[ 0.73194003]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.constant.variance</td><td>[ 9.10121686]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.white.variance</td><td>[  1.00000000e-06]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.branchkernelparam.Bv</td><td>[[ 3.09583718]]</td><td>None</td><td>(none)</td></tr><tr><td>model.kern.branchkernelparam.kern.lengthscales</td><td>[ 2.69714807]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.branchkernelparam.kern.variance</td><td>[ 1.58985697]</td><td>None</td><td>+ve</td></tr><tr><td>model.logPhi</td><td>[[ -1.99995576e-12  -2.76310211e+01  -2.76310211e+01 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> ..., </br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -9.00000000e+00</br>   -9.00000000e+00  -9.00000000e+00]</br> [ -9.00000000e+00  -9.00000000e+00  -9.00000000e+00 ...,  -2.76310211e+01</br>   -4.15069013e+00  -1.58789466e-02]]</td><td>None</td><td>(none)</td></tr></table>
